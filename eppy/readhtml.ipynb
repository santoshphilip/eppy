# %%
from bs4 import BeautifulSoup, NavigableString, Tag
fname = "resources/outputfiles/V_7_2/5ZoneCAVtoVAVWarmestTempFlowTable_ABUPS.html"
soup = BeautifulSoup(open(fname, 'r'))

# %%
btables = soup.find_all(['p', 'table', 'hr'])

# %%
atables = soup.hr.find_all(['p', 'table', 'hr'])

# %%
for i, t in enumerate(btables):
    if t.name == 'hr':
        for j in t:
#             print j.name
            pass

# %%
ctables = soup.hr.find_all()

# %%
for child in soup.body:
    print child.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d2a9d01e62cd> in <module>()
#       1 for child in soup.body:
# ----> 2     print child.name
#
# /Users/santosh/.virtualenvs/eplus/lib/python2.7/site-packages/bs4/element.pyc in __getattr__(self, attr)
#     665             raise AttributeError(
#     666                 "'%s' object has no attribute '%s'" % (
# --> 667                     self.__class__.__name__, attr))
#     668
#     669     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'name'

# %%
len(soup)
# Out:
# 4

# %%
for i in soup:
# Out:
#   File "<ipython-input-8-3856909d8bca>", line 1
#     for i in soup:
#                   ^
# SyntaxError: unexpected EOF while parsing

# %%
soup.find_all('p')
# Out:
# [<p><a href="#toc" style="float: right">Table of Contents</a></p>,
#  <p>Program Version:<b>EnergyPlus-Windows-OMP-32 7.2.0.006, YMD=2013.01.28 16:38</b></p>,
#  <p>Tabular Output Report in Format: <b>HTML</b></p>,
#  <p>Building: <b>Building</b></p>,
#  <p>Environment: <b>San Francisco Intl Ap CA USA TMY3 WMO#=724940</b></p>,
#  <p>Simulation Timestamp: <b>2013-01-28
#   16:38:08</b></p>,
#  <p><a href="#toc" style="float: right">Table of Contents</a></p>,
#  <p>Report:<b> Annual Building Utility Performance Summary</b></p>,
#  <p>For:<b> Entire Facility</b></p>,
#  <p>Timestamp: <b>2013-01-28
#     16:38:08</b></p>,
#  <p><b>Table of Contents</b></p>]

# %%
print soup.next
# Out:
# None

# %%
p = soup.find_all('p')

# %%
p[0].children.next()
# Out:
# <a href="#toc" style="float: right">Table of Contents</a>

# %%
hr = soup.hr.children

# %%
hr.next()
# Out:
# u'\n'

# %%
for i in hr:
    print i.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-6ec4fc9b09b9> in <module>()
#       1 for i in hr:
# ----> 2     print i.name
#
# /Users/santosh/.virtualenvs/eplus/lib/python2.7/site-packages/bs4/element.pyc in __getattr__(self, attr)
#     665             raise AttributeError(
#     666                 "'%s' object has no attribute '%s'" % (
# --> 667                     self.__class__.__name__, attr))
#     668
#     669     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'name'
# p

# %%
hr = soup.hr.children

# %%
br = soup.hr.br

# %%
for i in soup.hr.descendants:
    if i.name not in ( 'tr', 'td', None, 'br'):
        if i.name == 'p':
            print i
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-cdd2bde62ff2> in <module>()
#       1 for i in soup.hr.descendants:
# ----> 2     if i.name not in ( 'tr', 'td', None, 'br'):
#       3         if i.name == 'p':
#       4             print i
#
# /Users/santosh/.virtualenvs/eplus/lib/python2.7/site-packages/bs4/element.pyc in __getattr__(self, attr)
#     665             raise AttributeError(
#     666                 "'%s' object has no attribute '%s'" % (
# --> 667                     self.__class__.__name__, attr))
#     668
#     669     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'name'

# %%
pr = soup.table.next_siblings

# %%
for i in pr:
    print i.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-9407ae26a156> in <module>()
#       1 for i in pr:
# ----> 2     print i.name
#
# /Users/santosh/.virtualenvs/eplus/lib/python2.7/site-packages/bs4/element.pyc in __getattr__(self, attr)
#     665             raise AttributeError(
#     666                 "'%s' object has no attribute '%s'" % (
# --> 667                     self.__class__.__name__, attr))
#     668
#     669     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'name'

# %%
print pr.previous_sibling
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-9735192ee4f6> in <module>()
# ----> 1 print pr.previous_sibling
#
# AttributeError: 'generator' object has no attribute 'previous_sibling'

# %%
pr = soup.table.previous_elements

# %%
for i in pr:
    try:
        name = i.name
    except AttributeError, e:
        continue    
    if i.name not in ('br', None):
        if i.name == 'hr':
            break
        print i
# Out:
# <b>Site and Source Energy</b>
# <b></b>
# <b>Values gathered over      8760.00 hours</b>
# <b>2013-01-28
#     16:38:08</b>
# <p>Timestamp: <b>2013-01-28
#     16:38:08</b></p>
# <b> Entire Facility</b>
# <p>For:<b> Entire Facility</b></p>
# <b> Annual Building Utility Performance Summary</b>
# <p>Report:<b> Annual Building Utility Performance Summary</b></p>
# <a name="AnnualBuildingUtilityPerformanceSummary::EntireFacility"></a>
# <a href="#toc" style="float: right">Table of Contents</a>
# <p><a href="#toc" style="float: right">Table of Contents</a></p>

# %%
tb = soup.find_all('table')

# %%
for el in soup.table.next:
    if el.name == 'table':
        print el.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-e40149827360> in <module>()
#       1 for el in soup.table.next:
# ----> 2     if el.name == 'table':
#       3         print el.name
#
# AttributeError: 'unicode' object has no attribute 'name'

# %%
d = soup.body.next_element

# %%
e = soup.table.next_elements

# %%
def has_name(i):
    try:
        name = i.name
        return True
    except AttributeError, e:
        return False    


pr = soup.table.previous_elements
for i in pr:
    if not has_name(i):
        continue
    if i.name not in ('br', None):
        if i.name == 'hr':
            break
        print i.name
e = soup.table.next_elements
for j in e:
    if not has_name(j):
        continue
    if j.name == 'table':
        print j.name
        pr = j.previous_elements
        for i in pr:
            if not has_name(i):
                continue
            if i.name not in ('br', None):
                if i.name in ('table', 'hr', 'tr', 'td'):
                    break
                print i.name
# Out:
# b
# b
# b
# b
# p
# b
# p
# b
# p
# a
# a
# p
# table
# b
# table
# b
# table
# b
# table
# b
# i
# table
# b
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table

# %%
def has_name(i):
    try:
        name = i.name
        return True
    except AttributeError, e:
        return False    

e = soup.p.next_elements
for j in e:
    if not has_name(j):
        continue
    if j.name == 'table':
        print j.name
        pr = j.previous_elements
        for i in pr:
            if not has_name(i):
                continue
            if i.name not in ('br', None):
                if i.name in ('table', 'hr', 'tr', 'td'):
                    break
                print i.name
# Out:
# table
# b
# b
# b
# b
# p
# b
# p
# b
# p
# a
# a
# p
# table
# b
# table
# b
# table
# b
# table
# b
# i
# table
# b
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table

# %%
def has_name(i):
    try:
        name = i.name
        return True
    except AttributeError, e:
        return False    

all = []
e = soup.p.next_elements
for j in e:
    tabletup = []
    if not has_name(j):
        continue
    if j.name == 'table':
        print j.name
        beforetable = []
        pr = j.previous_elements
        for i in pr:
            if not has_name(i):
                continue
            if i.name not in ('br', None):
                if i.name in ('table', 'hr', 'tr', 'td'):
                    break
                print i.name
                beforetable.append(i.name)
        beforetable.reverse()
        tabletup.append(beforetable)
        tabletup.append(j.name)
    if tabletup:
        all.append(tabletup)
# Out:
# table
# b
# b
# b
# b
# p
# b
# p
# b
# p
# a
# a
# p
# table
# b
# table
# b
# table
# b
# table
# b
# i
# table
# b
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table

# %%
def has_name(i):
    try:
        name = i.name
        return True
    except AttributeError, e:
        return False    

all = []
e = soup.p.next_elements
for j in e:
    tabletup = []
    if not has_name(j):
        continue
    if j.name == 'table':
        print j.name
        beforetable = []
        pr = j.previous_elements
        for i in pr:
            if not has_name(i):
                continue
            if i.name not in ('br', None):
                if i.name in ('table', 'hr', 'tr', 'td'):
                    break
                print i.name
                beforetable.append(i)
        beforetable.reverse()
        tabletup.append(beforetable)
        tabletup.append(j)
    if tabletup:
        all.append(tabletup)
# Out:
# table
# b
# b
# b
# b
# p
# b
# p
# b
# p
# a
# a
# p
# table
# b
# table
# b
# table
# b
# table
# b
# i
# table
# b
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table

# %%
for line in all[0][0]:
    if line.name == 'p':
        print line.get_text()
# Out:
# Table of Contents
# Report: Annual Building Utility Performance Summary
# For: Entire Facility
# Timestamp: 2013-01-28
#     16:38:08

# %%
fname = "resources/outputfiles/V_8_1/1050PageMillRoadTable.html"
soup = BeautifulSoup(open(fname, 'r'))

# %%
all = []
e = soup.p.next_elements
for j in e:
    tabletup = []
    if not has_name(j):
        continue
    if j.name == 'table':
        print j.name
        beforetable = []
        pr = j.previous_elements
        for i in pr:
            if not has_name(i):
                continue
            if i.name not in ('br', None):
                if i.name in ('table', 'hr', 'tr', 'td'):
                    break
                if i.parent.name == "p":
                    print i.name, "parent", i.parent.name
                else:
                    print i.name
                    beforetable.append(i)
        beforetable.reverse()
        tabletup.append(beforetable)
        tabletup.append(j)
    if tabletup:
        all.append(tabletup)
# Out:
# table
# b
# b
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# table
# b
# table
# b
# table
# b
# i
# table
# b
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b
# table
# b
# table
# b
# table
# b
# b
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# table
# b
# table
# b
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# table
# b
# i
# table
# b
# i
# table
# b
# table
# b
# i
# table
# b
# table
# b
# table
# b
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# b parent p
# p
# b parent p
# p
# b parent p
# p
# a
# a parent p
# p
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b
# table
# b

# %%
for block in all:
    for line in block[0]:
        print line.get_text()
    print '- Table -----'
# Out:
# Table of Contents
#
# Report: Annual Building Utility Performance Summary
# For: Entire Facility
# Timestamp: 2014-01-13
#     16:47:19
# Values gathered over      8760.00 hours
#
# Site and Source Energy
# - Table -----
# Site to Source Energy Conversion Factors
# - Table -----
# Building Area
# - Table -----
# End Uses
# - Table -----
# Note: Natural gas appears to be the principal heating source based on energy usage.
# End Uses By Subcategory
# - Table -----
# Normalized Metrics
# Utility Use Per Conditioned Floor Area
# - Table -----
# Utility Use Per Total Floor Area
# - Table -----
# Electric Loads Satisfied
# - Table -----
# On-Site Thermal Sources
# - Table -----
# Water Source Summary
# - Table -----
# Setpoint Not Met Criteria
# - Table -----
# Comfort and Setpoint Not Met Summary
# - Table -----
# Table of Contents
#
# Report: Input Verification and Results Summary
# For: Entire Facility
# Timestamp: 2014-01-13
#     16:47:19
# General
# - Table -----
# ENVELOPE
# Window-Wall Ratio
# - Table -----
# Conditioned Window-Wall Ratio
# - Table -----
# Skylight-Roof Ratio
# - Table -----
# PERFORMANCE
# Zone Summary
# - Table -----
# Table of Contents
#
# Report: Climatic Data Summary
# For: Entire Facility
# Timestamp: 2014-01-13
#     16:47:19
# SizingPeriod:DesignDay
# - Table -----
# Weather Statistics File
# - Table -----
# Table of Contents
#
# Report: Envelope Summary
# For: Entire Facility
# Timestamp: 2014-01-13
#     16:47:19
# Opaque Exterior
# - Table -----
# Exterior Fenestration
# - Table -----
# Interior Fenestration
# - Table -----
# Exterior Door
# - Table -----
# Table of Contents
#
# Report: Equipment Summary
# For: Entire Facility
# Timestamp: 2014-01-13
#     16:47:19
# Central Plant
# - Table -----
# Cooling Coils
# - Table -----
# Nominal values are gross at rated conditions, i.e., the supply air fan heat and electric power NOT accounted for.
# DX Cooling Coils
# - Table -----
# ANSI/AHRI ratings include supply fan
# DX Heating Coils
# - Table -----
# Heating Coils
# - Table -----
# Nominal values are gross at rated conditions, i.e., the supply air fan heat and electric power NOT accounted for.
# Fans
# - Table -----
# Pumps
# - Table -----
# Service Water Heating
# - Table -----
# VAV DX Cooling Standard Rating Details
# - Table -----
# Table of Contents
#
# Report: Component Cost Economics Summary
# For: Entire Facility
# Timestamp: 2014-01-13
#     16:47:19
# Construction Cost Estimate Summary
# - Table -----
# Cost Line Item Details
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_1_SEC_1 PEOPLE
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_2_SEC_1 PEOPLE
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_1_SEC_2 PEOPLE
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_2_SEC_2 PEOPLE
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_1_SEC_3 PEOPLE
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_2_SEC_3 PEOPLE
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_1_SEC_4 PEOPLE
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_2_SEC_4 PEOPLE
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_1_SEC_5 PEOPLE
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_2_SEC_5 PEOPLE
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_1_SEC_1
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_2_SEC_1
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_1_SEC_2
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_2_SEC_2
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_1_SEC_3
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_2_SEC_3
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_1_SEC_4
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_2_SEC_4
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_1_SEC_5
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OCCUPANT COMFORT DATA SUMMARY
# For: ZN_1_FLR_2_SEC_5
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: SOURCE ENERGY USE SUMMARY
# For: Meter
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: EMISSIONS DATA SUMMARY
# For: Meter
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OUTDOOR AIR SUMMARY
# For: ZN_1_FLR_1_SEC_1
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OUTDOOR AIR SUMMARY
# For: ZN_1_FLR_2_SEC_1
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OUTDOOR AIR SUMMARY
# For: ZN_1_FLR_1_SEC_2
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OUTDOOR AIR SUMMARY
# For: ZN_1_FLR_2_SEC_2
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OUTDOOR AIR SUMMARY
# For: ZN_1_FLR_1_SEC_3
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OUTDOOR AIR SUMMARY
# For: ZN_1_FLR_2_SEC_3
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OUTDOOR AIR SUMMARY
# For: ZN_1_FLR_1_SEC_4
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OUTDOOR AIR SUMMARY
# For: ZN_1_FLR_2_SEC_4
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OUTDOOR AIR SUMMARY
# For: ZN_1_FLR_1_SEC_5
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OUTDOOR AIR SUMMARY
# For: ZN_1_FLR_2_SEC_5
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: VENTILATION LOAD COMPONENTS
# For: ZN_1_FLR_1_SEC_1
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: VENTILATION LOAD COMPONENTS
# For: ZN_1_FLR_2_SEC_1
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: VENTILATION LOAD COMPONENTS
# For: ZN_1_FLR_1_SEC_2
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: VENTILATION LOAD COMPONENTS
# For: ZN_1_FLR_2_SEC_2
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: VENTILATION LOAD COMPONENTS
# For: ZN_1_FLR_1_SEC_3
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: VENTILATION LOAD COMPONENTS
# For: ZN_1_FLR_2_SEC_3
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: VENTILATION LOAD COMPONENTS
# For: ZN_1_FLR_1_SEC_4
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: VENTILATION LOAD COMPONENTS
# For: ZN_1_FLR_2_SEC_4
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: VENTILATION LOAD COMPONENTS
# For: ZN_1_FLR_1_SEC_5
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: VENTILATION LOAD COMPONENTS
# For: ZN_1_FLR_2_SEC_5
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OVERALL HVAC AIR SYSTEM LOADS
# For: PVAV_REHEAT_1
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: OVERALL HVAC SYSTEM ENERGY
# For: Meter
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMPONENTS OF PEAK ELECTRICAL DEMAND
# For: Meter
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMPONENTS OF PEAK NET ELECTRICAL DEMAND
# For: Meter
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: SETPOINTS NOT MET WITH TEMPERATURES
# For: ZN_1_FLR_1_SEC_1
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: SETPOINTS NOT MET WITH TEMPERATURES
# For: ZN_1_FLR_2_SEC_1
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: SETPOINTS NOT MET WITH TEMPERATURES
# For: ZN_1_FLR_1_SEC_2
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: SETPOINTS NOT MET WITH TEMPERATURES
# For: ZN_1_FLR_2_SEC_2
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: SETPOINTS NOT MET WITH TEMPERATURES
# For: ZN_1_FLR_1_SEC_3
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: SETPOINTS NOT MET WITH TEMPERATURES
# For: ZN_1_FLR_2_SEC_3
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: SETPOINTS NOT MET WITH TEMPERATURES
# For: ZN_1_FLR_1_SEC_4
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: SETPOINTS NOT MET WITH TEMPERATURES
# For: ZN_1_FLR_2_SEC_4
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: SETPOINTS NOT MET WITH TEMPERATURES
# For: ZN_1_FLR_1_SEC_5
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: SETPOINTS NOT MET WITH TEMPERATURES
# For: ZN_1_FLR_2_SEC_5
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMFORT REPORT - SIMPLE 55
# For: ZN_1_FLR_1_SEC_1
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMFORT REPORT - SIMPLE 55
# For: ZN_1_FLR_2_SEC_1
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMFORT REPORT - SIMPLE 55
# For: ZN_1_FLR_1_SEC_2
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMFORT REPORT - SIMPLE 55
# For: ZN_1_FLR_2_SEC_2
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMFORT REPORT - SIMPLE 55
# For: ZN_1_FLR_1_SEC_3
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMFORT REPORT - SIMPLE 55
# For: ZN_1_FLR_2_SEC_3
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMFORT REPORT - SIMPLE 55
# For: ZN_1_FLR_1_SEC_4
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMFORT REPORT - SIMPLE 55
# For: ZN_1_FLR_2_SEC_4
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMFORT REPORT - SIMPLE 55
# For: ZN_1_FLR_1_SEC_5
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: COMFORT REPORT - SIMPLE 55
# For: ZN_1_FLR_2_SEC_5
# Timestamp: 2014-01-13
#     16:47:19
# Custom Monthly Report
# - Table -----
# Table of Contents
#
# Report: Economics Results Summary Report
# For: Entire Facility
# Timestamp: 2014-01-13
#     16:47:19
# Annual Cost
# - Table -----
# Tariff Summary
# - Table -----
# Table of Contents
#
# Report: Tariff Report
# For: PGE_E-19_MEDIUMGENERALTOUDEMANDSERVICE
# Timestamp: 2014-01-13
#     16:47:19
# General
# - Table -----
# Categories
# - Table -----
# Charges
# - Table -----
# Corresponding Sources for Charges
# - Table -----
# Ratchets
# - Table -----
# Qualifies
# - Table -----
# Native Variables
# - Table -----
# Other Variables
# - Table -----
# Table of Contents
#
# Report: Tariff Report
# For: PGE_A-10MEDIUMGENERALDEMANDSERVICE
# Timestamp: 2014-01-13
#     16:47:19
# General
# - Table -----
# Categories
# - Table -----
# Charges
# - Table -----
# Corresponding Sources for Charges
# - Table -----
# Ratchets
# - Table -----
# Qualifies
# - Table -----
# Native Variables
# - Table -----
# Other Variables
# - Table -----
# Table of Contents
#
# Report: Tariff Report
# For: PGE_A-1SMALLGENERALSERVICE
# Timestamp: 2014-01-13
#     16:47:19
# General
# - Table -----
# Categories
# - Table -----
# Charges
# - Table -----
# Corresponding Sources for Charges
# - Table -----
# Ratchets
# - Table -----
# Qualifies
# - Table -----
# Native Variables
# - Table -----
# Other Variables
# - Table -----
# Table of Contents
#
# Report: Tariff Report
# For: CA_EIAMONTHLYRATEGAS
# Timestamp: 2014-01-13
#     16:47:19
# General
# - Table -----
# Categories
# - Table -----
# Charges
# - Table -----
# Corresponding Sources for Charges
# - Table -----
# Ratchets
# - Table -----
# Qualifies
# - Table -----
# Native Variables
# - Table -----
# Other Variables
# - Table -----

# %%
pk = ([(i, line.get_text(), block[-1]) for line in block[0] if 'PEAK' in line.get_text()] for i, block in enumerate(all))
imgs = [str(p[-1]) for p in pk if p]
HTML(imgs[1])
# Out:
# (79, u'Report: COMPONENTS OF PEAK NET ELECTRICAL DEMAND', <table border="1" cellpadding="4" cellspacing="0">
# <tr><td></td>
# <td align="right">ELECTRICITYNET:FACILITY [J]</td>
# <td align="right">ELECTRICITYNET:FACILITY {Maximum}[W]</td>
# <td align="right">ELECTRICITYNET:FACILITY {TIMESTAMP}</td>
# <td align="right">INTERIORLIGHTS:ELECTRICITY {AT MAX/MIN} [W]</td>
# <td align="right">INTERIOREQUIPMENT:ELECTRICITY {AT MAX/MIN} [W]</td>
# <td align="right">FANS:ELECTRICITY {AT MAX/MIN} [W]</td>
# <td align="right">HEATING:ELECTRICITY {AT MAX/MIN} [W]</td>
# <td align="right">COOLING:ELECTRICITY {AT MAX/MIN} [W]</td>
# <td align="right">EXTERIORLIGHTS:ELECTRICITY [Invalid/Undefined]</td>
# <td align="right">PUMPS:ELECTRICITY {AT MAX/MIN} [W]</td>
# <td align="right">HEATREJECTION:ELECTRICITY [Invalid/Undefined]</td>
# <td align="right">EXTERIOREQUIPMENT:ELECTRICITY [Invalid/Undefined]</td>
# <td align="right">HUMIDIFICATION:ELECTRICITY [Invalid/Undefined]</td>
# <td align="right">HEATRECOVERY:ELECTRICITY [Invalid/Undefined]</td>
# <td align="right">WATERSYSTEMS:ELECTRICITY [Invalid/Undefined]</td>
# <td align="right">REFRIGERATION:ELECTRICITY [Invalid/Undefined]</td>
# <td align="right">GENERATORS:ELECTRICITY [Invalid/Undefined]</td>
# <td align="right">ELECTRICITYPRODUCED:FACILITY [Invalid/Undefined]</td>
# </tr>
# <tr>
# <td align="right">January</td>
# <td align="right">0.171128E+12</td>
# <td align="right">  157049.426</td>
# <td align="right">31-JAN-13:00</td>
# <td align="right">   71973.843</td>
# <td align="right">   53980.383</td>
# <td align="right">   11549.438</td>
# <td align="right">       0.000</td>
# <td align="right">   19536.328</td>
# <td align="right">       0.000</td>
# <td align="right">       9.434</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# </tr>
# <tr>
# <td align="right">February</td>
# <td align="right">0.160835E+12</td>
# <td align="right">  193039.840</td>
# <td align="right">03-FEB-13:00</td>
# <td align="right">   71973.843</td>
# <td align="right">   53980.383</td>
# <td align="right">   12471.156</td>
# <td align="right">       0.000</td>
# <td align="right">   54492.992</td>
# <td align="right">       0.000</td>
# <td align="right">     121.467</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# </tr>
# <tr>
# <td align="right">March</td>
# <td align="right">0.212043E+12</td>
# <td align="right">  208946.687</td>
# <td align="right">10-MAR-14:30</td>
# <td align="right">   71973.843</td>
# <td align="right">   53980.383</td>
# <td align="right">   13828.046</td>
# <td align="right">       0.000</td>
# <td align="right">   69138.247</td>
# <td align="right">       0.000</td>
# <td align="right">      26.168</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# </tr>
# <tr>
# <td align="right">April</td>
# <td align="right">0.181469E+12</td>
# <td align="right">  201248.208</td>
# <td align="right">14-APR-15:00</td>
# <td align="right">   71973.843</td>
# <td align="right">   53980.383</td>
# <td align="right">   13769.302</td>
# <td align="right">       0.000</td>
# <td align="right">   61507.074</td>
# <td align="right">       0.000</td>
# <td align="right">      17.607</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# </tr>
# <tr>
# <td align="right">May</td>
# <td align="right">0.203926E+12</td>
# <td align="right">  197284.804</td>
# <td align="right">11-MAY-15:00</td>
# <td align="right">   71973.843</td>
# <td align="right">   53980.383</td>
# <td align="right">   12941.561</td>
# <td align="right">       0.000</td>
# <td align="right">   58373.490</td>
# <td align="right">       0.000</td>
# <td align="right">      15.528</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# </tr>
# <tr>
# <td align="right">June</td>
# <td align="right">0.232938E+12</td>
# <td align="right">  213394.890</td>
# <td align="right">13-JUN-15:00</td>
# <td align="right">   71973.843</td>
# <td align="right">   53980.383</td>
# <td align="right">   13916.013</td>
# <td align="right">       0.000</td>
# <td align="right">   73510.289</td>
# <td align="right">       0.000</td>
# <td align="right">      14.363</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# </tr>
# <tr>
# <td align="right">July</td>
# <td align="right">0.230901E+12</td>
# <td align="right">  235258.279</td>
# <td align="right">12-JUL-15:15</td>
# <td align="right">   71973.843</td>
# <td align="right">   53980.383</td>
# <td align="right">   14525.904</td>
# <td align="right">       0.000</td>
# <td align="right">   94771.056</td>
# <td align="right">       0.000</td>
# <td align="right">       7.093</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# </tr>
# <tr>
# <td align="right">August</td>
# <td align="right">0.255759E+12</td>
# <td align="right">  228777.354</td>
# <td align="right">30-AUG-14:00</td>
# <td align="right">   71973.843</td>
# <td align="right">   53980.383</td>
# <td align="right">   15823.009</td>
# <td align="right">       0.000</td>
# <td align="right">   86987.338</td>
# <td align="right">       0.000</td>
# <td align="right">      12.781</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# </tr>
# <tr>
# <td align="right">September</td>
# <td align="right">0.245803E+12</td>
# <td align="right">  246369.600</td>
# <td align="right">29-SEP-14:30</td>
# <td align="right">   71973.843</td>
# <td align="right">   53980.383</td>
# <td align="right">   21705.841</td>
# <td align="right">       0.000</td>
# <td align="right">   98703.816</td>
# <td align="right">       0.000</td>
# <td align="right">       5.717</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# </tr>
# <tr>
# <td align="right">October</td>
# <td align="right">0.215025E+12</td>
# <td align="right">  216010.129</td>
# <td align="right">10-OCT-14:00</td>
# <td align="right">   71973.843</td>
# <td align="right">   53980.383</td>
# <td align="right">   18295.672</td>
# <td align="right">       0.000</td>
# <td align="right">   71743.938</td>
# <td align="right">       0.000</td>
# <td align="right">      16.292</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <td align="right">       0.000</td>
# <t

# %%
# Out:
# 2

# %%
pr = soup.table.previous_elements
for i in pr:
    if i.name not in ('br', None):
        if i.name == 'hr':
            break
        print i.get_text()
e = soup.table.next_elements
for j in e:
    if j.name == 'table':
        print j.name
        pr = j.previous_elements
        for i in pr:
            if i.name not in ('br', None):
                if i.name in ('table', 'hr', 'tr', 'td'):
                    break
                print i.get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-aa34f52be7f0> in <module>()
#       1 pr = soup.table.previous_elements
#       2 for i in pr:
# ----> 3     if i.name not in ('br', None):
#       4         if i.name == 'hr':
#       5             break
#
# /Users/santosh/.virtualenvs/eplus/lib/python2.7/site-packages/bs4/element.pyc in __getattr__(self, attr)
#     665             raise AttributeError(
#     666                 "'%s' object has no attribute '%s'" % (
# --> 667                     self.__class__.__name__, attr))
#     668
#     669     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'name'

# %%
pr = soup.table.previous_elements
for i in pr:
    if i.name not in ('br', None):
        if i.name == 'hr':
            break
        if i.name == 'p':
            print i.get_text()
e = soup.table.next_elements
for j in e:
    if j.name == 'table':
        print j.name
        pr = j.previous_elements
        for i in pr:
            if i.name not in ('br', None):
                if i.name in ('table', 'hr', 'tr', 'td'):
                    break
                print i.get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-faac7f6a7b01> in <module>()
#       1 pr = soup.table.previous_elements
#       2 for i in pr:
# ----> 3     if i.name not in ('br', None):
#       4         if i.name == 'hr':
#       5             break
#
# /Users/santosh/.virtualenvs/eplus/lib/python2.7/site-packages/bs4/element.pyc in __getattr__(self, attr)
#     665             raise AttributeError(
#     666                 "'%s' object has no attribute '%s'" % (
# --> 667                     self.__class__.__name__, attr))
#     668
#     669     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'name'

# %%
soup.table.previousSibling?

# %%
from IPython.display import HTML

# %%
print str(soup.table)
# Out:
# <table border="1" cellpadding="4" cellspacing="0">
# <tr><td></td>
# <td align="right">Total Energy [kWh]</td>
# <td align="right">Energy Per Total Building Area [kWh/m2]</td>
# <td align="right">Energy Per Conditioned Building Area [kWh/m2]</td>
# </tr>
# <tr>
# <td align="right">Total Site Energy</td>
# <td align="right">    47694.47</td>
# <td align="right">       51.44</td>
# <td align="right">       51.44</td>
# </tr>
# <tr>
# <td align="right">Net Site Energy</td>
# <td align="right">    47694.47</td>
# <td align="right">       51.44</td>
# <td align="right">       51.44</td>
# </tr>
# <tr>
# <td align="right">Total Source Energy</td>
# <td align="right">   140159.10</td>
# <td align="right">      151.16</td>
# <td align="right">      151.16</td>
# </tr>
# <tr>
# <td align="right">Net Source Energy</td>
# <td align="right">   140159.10</td>
# <td align="right">      151.16</td>
# <td align="right">      151.16</td>
# </tr>
# </table>

# %%
HTML(str(soup.table))
# Out:
# <table border="1" cellpadding="4" cellspacing="0">
# <tr><td></td>
# <td align="right">Total Energy [kWh]</td>
# <td align="right">Energy Per Total Building Area [kWh/m2]</td>
# <td align="right">Energy Per Conditioned Building Area [kWh/m2]</td>
# </tr>
# <tr>
# <td align="right">Total Site Energy</td>
# <td align="right">    47694.47</td>
# <td align="right">       51.44</td>
# <td align="right">       51.44</td>
# </tr>
# <tr>
# <td align="right">Net Site Energy</td>
# <td align="right">    47694.47</td>
# <td align="right">       51.44</td>
# <td align="right">       51.44</td>
# </tr>
# <tr>
# <td align="right">Total Source Energy</td>
# <td align="right">   140159.10</td>
# <td align="right">      151.16</td>
# <td align="right">      151.16</td>
# </tr>
# <tr>
# <td align="right">Net Source Energy</td>
# <td align="right">   140159.10</td>
# <td align="right">      151.16</td>
# <td align="right">      151.16</td>
# </tr>
# </table>

# %%
for t in soup.table.next_elements:
    if t.name == 'table':
        HTML(str(t))
        break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-ec63312f6647> in <module>()
#       1 for t in soup.table.next_elements:
# ----> 2     if t.name == 'table':
#       3         HTML(str(t))
#       4         break
#
# /Users/santosh/.virtualenvs/eplus/lib/python2.7/site-packages/bs4/element.pyc in __getattr__(self, attr)
#     665             raise AttributeError(
#     666                 "'%s' object has no attribute '%s'" % (
# --> 667                     self.__class__.__name__, attr))
#     668
#     669     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'name'

# %%
HTML(str(t))

# %%
ts = soup.table.next_elements

# %%
l = [str(i) for i in ts if i.name == 'table']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-c033ef8b668c> in <module>()
# ----> 1 l = [str(i) for i in ts if i.name == 'table']
#
# /Users/santosh/.virtualenvs/eplus/lib/python2.7/site-packages/bs4/element.pyc in __getattr__(self, attr)
#     665             raise AttributeError(
#     666                 "'%s' object has no attribute '%s'" % (
# --> 667                     self.__class__.__name__, attr))
#     668
#     669     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'name'

# %%
HTML(l[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-c31a7a062543> in <module>()
# ----> 1 HTML(l[-1])
#
# NameError: name 'l' is not defined
